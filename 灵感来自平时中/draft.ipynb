# %%
my_dict = {
    "key1": "value1",
    "key2": "value2"
}

print("key1" in my_dict)
print("value1" in my_dict.values())
print("value1" in my_dict)
# Out:
# True
# True
# False

# %%
n = 200
m = 100

class MyClass:
    pass

def func_base(n):
    for _ in range(n):
        MyClass()

def func_loop(m):
    for _ in range(m):
        func_base(n)

def my_func():
    func_loop(m)

my_func()

# %%
def func():
    print("Hello, World!")

func()
# Out:
# Hello, World!

# %%
from typing import Optional

def get_value(key: str, dictionary: dict) -> Optional[str]:
    return dictionary.get(key)

# Optional: 可能是 None

# %%
for i in range(5, 0, -1): # start, stop, step
    print(i)
# Out:
# 5
# 4
# 3
# 2
